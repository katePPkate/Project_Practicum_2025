# %% [markdown]
# # Импорты библиотек

# %%
import gradio as gr
import pandas as pd
# Добавьте необходимые библиотеки здесь

# %% [markdown]
# # Чтение данных

# %%
df_path = "/your/path/to/file.csv"

df = df.read_csv(df_path)

df.head()

# %% [markdown]
# # Чистка и подготовка данных

# %%
# Ваш код из чек-пойнта 2 здесь

# %% [markdown]
# # Дашборд

# %%
# Код для демонстрации дашборда на gradio
# Пример

import gradio as gr
import pandas as pd
import plotly.express as px

# Пример небольшого набора данных
data = pd.DataFrame({
    "Category": ["A", "A", "B", "B", "C", "C"] * 5,
    "Value": [10, 15, 7, 12, 9, 20] * 5,
    "Year": [2020, 2021, 2020, 2021, 2020, 2021] * 5
})


def plot_data(category, year_range):
    """Фукнция для построения графика plotly"""
    filtered = data[
        (data["Category"] == category) &
        (data["Year"].between(year_range[0], year_range[1]))
    ]
    fig = px.bar(filtered, x="Year", y="Value", color="Category",
                 title=f"Значения для категории {category}",
                 labels={"Value": "Значение", "Year": "Год"})
    return fig


# Интерфейс Gradio
with gr.Blocks() as demo:
    # Заголовок
    gr.Markdown("## 📊 Пример дэшборда с фильтрами")

    with gr.Row():
        # Фильтр по категории
        category = gr.Dropdown(choices=sorted(data["Category"].unique()),
                               label="Категория", value="A")

        # Фильтр по годам
        year_range = gr.Slider(minimum=2020, maximum=2021, step=1,
                               value=[2020, 2021], label="Диапазон лет", interactive=True)

    # Плейсхолдер для графика
    plot = gr.Plot()

    # Кнопка для построения графика
    btn = gr.Button("Построить график")

    # Функция построения графика, которая вызывается при нажатии на кнопку
    btn.click(plot_data, inputs=[category, year_range], outputs=plot)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a93680b5abb7a56043.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a93680b5abb7a56043.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
